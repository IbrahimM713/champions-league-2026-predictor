# %%
import cloudscraper
from bs4 import BeautifulSoup
import pandas as pd
import time
from io import StringIO
import random

# %%
# Enhanced scraper with better rate limiting and realistic browser behavior
def create_enhanced_scraper():
    """Create a scraper with realistic browser headers to avoid detection"""
    scraper = cloudscraper.create_scraper(
        browser={
            'browser': 'chrome',
            'platform': 'darwin',  # macOS
            'desktop': True
        }
    )
    # Add realistic headers to appear more human-like
    scraper.headers.update({
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept-Encoding': 'gzip, deflate, br',
        'Cache-Control': 'no-cache',
        'Pragma': 'no-cache',
        'Sec-Fetch-Dest': 'document',
        'Sec-Fetch-Mode': 'navigate',
        'Sec-Fetch-Site': 'none',
        'Upgrade-Insecure-Requests': '1'
    })
    return scraper

def smart_request(scraper, url, max_retries=3, base_delay=5):
    """
    Make requests with intelligent rate limiting and retry logic
    
    Why this is important:
    - Exponential backoff: Wait longer after each failure
    - Random jitter: Prevents synchronized requests that look robotic
    - Multiple status code handling: Different responses for different errors
    - Timeout protection: Prevents hanging requests
    """
    for attempt in range(max_retries):
        try:
            # Add random delay to appear more human (except first attempt)
            if attempt > 0:
                jitter = random.uniform(0.5, 2.0)  # Random jitter
                delay = base_delay * (2 ** attempt) + jitter  # Exponential backoff + jitter
                print(f"  ⏳ Waiting {delay:.1f} seconds before retry...")
                time.sleep(delay)
            
            print(f"  📡 Requesting: {url.split('/')[-1]} (attempt {attempt + 1}/{max_retries})")
            response = scraper.get(url, timeout=30)
            
            if response.status_code == 200:
                print(f"  ✅ Success!")
                return response
            elif response.status_code == 429:
                # Rate limited - wait longer with exponential backoff
                wait_time = base_delay * (3 ** attempt) + random.uniform(5, 15)
                print(f"  🚫 Rate limited (429). Waiting {wait_time:.1f} seconds...")
                time.sleep(wait_time)
            elif response.status_code == 403:
                # Forbidden - might be blocked, wait even longer
                wait_time = base_delay * (4 ** attempt) + random.uniform(10, 30)
                print(f"  🔒 Forbidden (403). Waiting {wait_time:.1f} seconds...")
                time.sleep(wait_time)
            else:
                print(f"  ❌ Error {response.status_code}: {response.reason}")
                time.sleep(base_delay)
                
        except Exception as e:
            print(f"  💥 Request failed: {e}")
            time.sleep(base_delay + random.uniform(1, 5))
    
    print(f"  💀 Failed after {max_retries} attempts")
    return None

# Initialize enhanced scraper
scraper = create_enhanced_scraper()
standings_url = "https://fbref.com/en/comps/8/Champions-League-Stats"

# %%
# Selecting which years to pull data from
years = list(range(2026, 2023, -1))
all_matches = []
print(f"🎯 Scraping data for years: {years}")
# Out:
# 🎯 Scraping data for years: [2026, 2025, 2024]

# %%
scraper = cloudscraper.create_scraper()
url = "https://fbref.com/en/comps/8/Champions-League-Stats"
resp = scraper.get(url)   # no verify=False needed
soup = BeautifulSoup(resp.text, "html.parser")
standings_table = soup.select("table.stats_table")[0]
# Finding all of the a tags within the table, which contains the link to more data for each team
links = standings_table.find_all("a")
# Extracting the href properties from the links
links = [link.get("href") for link in links]
# Filtering the links to only include those that contain "/squads/", which is the pattern for team data pages
links = [l for l in links if l and "/squads/" in l]
# Constructing the full URLs for each team
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
# --- TEST MODE SWITCH ---
TEST_MODE = False   # flip to False for full scrape

if TEST_MODE:
    team_urls = team_urls[:2]        # only 1 team

#

for i, team_url in enumerate(team_urls):
    # Change team name to a readable format
    team_name = team_url.split("/")[-1].replace("-", " ").replace("_Stats", "")
    print(f"\n🏃 Processing team {i+1}/{len(team_urls)}: {team_name}")

    current_url = team_url

    for year in years:
        print(f"\n🏆 Season {year}: {current_url}")

        # Get team page with retries
        data = smart_request(scraper, current_url, max_retries=3, base_delay=3)
        if not data:
            print(f"    ❌ Failed to get team data for {team_name}, season {year}")
            break

        # Try to get matches data
        try:
            matches = pd.read_html(StringIO(data.text), match="Scores & Fixtures")
            if not matches:
                print(f"    ❌ No matches data for {team_name}, season {year}")
                break
            print(f"    📋 Matches found ({matches[0].shape[0]} rows)")
        except Exception as e:
            print(f"    ❌ Failed to parse matches for {team_name}, season {year}: {e}")
            break

        # ---------- Helper function for stats ---------- #
        def get_stats_data(data_type, url_pattern, table_match):
            print(f"    📊 Getting {data_type} data...")
            soup = BeautifulSoup(data.text, "html.parser")
            links = [a.get("href") for a in soup.find_all("a") if a.get("href")]
            links = [l for l in links if url_pattern in l]

            if not links:
                print(f"    ⚠️ No {data_type} links found")
                return None

            stats_url = f"https://fbref.com{links[0]}"
            stats_response = smart_request(scraper, stats_url, max_retries=2, base_delay=2)
            if not stats_response:
                print(f"    ❌ Failed request for {data_type} data")
                return None

            try:
                stats_df = pd.read_html(StringIO(stats_response.text), match=table_match)[0]
                if hasattr(stats_df.columns, "nlevels") and stats_df.columns.nlevels > 1:
                    stats_df.columns = stats_df.columns.droplevel()
                print(f"    ✅ {data_type} data loaded ({stats_df.shape[0]} rows)")
                return stats_df
            except Exception as e:
                print(f"    ❌ Failed to parse {data_type} data: {e}")
                return None

        # ---------- Collect stats ---------- #
        shooting   = get_stats_data("Shooting", "all_comps/shooting/", "Shooting"); time.sleep(random.uniform(1, 3))
        possession = get_stats_data("Possession", "all_comps/possession/", "Possession"); time.sleep(random.uniform(1, 3))
        gsc        = get_stats_data("Goal/Shot Creation", "all_comps/gca", "Goal and Shot Creation"); time.sleep(random.uniform(1, 3))
        defense    = get_stats_data("Defense", "all_comps/defense", "Defensive Actions"); time.sleep(random.uniform(1, 3))

        # ---------- Merge stats ---------- #
        try:
            team_data = matches[0].copy()
            print(f"    🔗 Starting merge with {team_data.shape[1]} base columns")

            # Merge helpers
            def safe_merge(df, source, cols, label):
                if source is not None:
                    keep = [c for c in cols if c in source.columns]
                    if len(keep) > 1:
                        # rename all columns except 'Date' to avoid duplicates
                        rename_map = {c: f"{c}_{label}" for c in keep if c != "Date"}
                        source_renamed = source[keep].rename(columns=rename_map)
                        df = df.merge(source_renamed, on="Date", how="left")
                        print(f"       + {label} ({len(keep)-1} cols)")
                return df

            # Merge each stats table
            team_data = safe_merge(team_data, shooting, ["Date", "Sh", "SoT", "Dist"], "shooting")
            team_data = safe_merge(team_data, possession,
                                   ["Date", "Touches", "Def Pen", "Def 3rd", "Mid 3rd",
                                    "Att 3rd", "Att Pen", "Succ%", "PrgDist", "1/3"],
                                   "poss")
            team_data = safe_merge(team_data, gsc, ["Date", "SCA", "PassLive"], "gsc")
            team_data = safe_merge(team_data, defense, ["Date", "Tkl+Int", "TklW", "Tkl%"], "def")

            # Add team & season info
            team_data["Team"] = team_name
            team_data["Season"] = f"{year-1}-{str(year)[-2:]}"
            all_matches.append(team_data)

            print(f"    ✅ Finished {team_name} {year-1}-{str(year)[-2:]} → {team_data.shape[1]} cols")

        except Exception as e:
            print(f"    ❌ Merge failed for {team_name}, season {year}: {e}")
            continue

        # ---------- Move to previous season ---------- #
        soup = BeautifulSoup(data.text, "html.parser")
        prev_link_tag = soup.find("a", string=lambda s: s and "Previous Season" in s)
        if prev_link_tag:
            current_url = f"https://fbref.com{prev_link_tag.get('href')}"
            print(f"➡️  Moving to previous season → {current_url}")
        else:
            print("❌ No previous season found — stopping loop")
            break

        # Respectful delay
        delay = random.uniform(10, 20)
        print(f"    ⏳ Cooling off {delay:.1f}s before next year...")
        time.sleep(delay)

    # Longer delay between teams
    team_delay = random.uniform(20, 40)
    print(f"✅ Completed {team_name}. Cooling off {team_delay:.1f}s before next team...\n")
    time.sleep(team_delay)
# Out:
# 🏃 Processing team 1/36: Liverpool Stats
#
# 🏆 Season 2026: https://fbref.com/en/squads/822bd0ba/Liverpool-Stats
#   📡 Requesting: Liverpool-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (48 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Liverpool-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (5 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Liverpool-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (5 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Liverpool-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (5 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Liverpool-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (5 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Liverpool Stats 2025-26 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/822bd0ba/2024-2025/Liverpool-Stats
#     ⏳ Cooling off 12.2s before next year...
#
# 🏆 Season 2025: https://fbref.com/en/squads/822bd0ba/2024-2025/Liverpool-Stats
#   📡 Requesting: Liverpool-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (56 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Liverpool-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (57 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Liverpool-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (57 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Liverpool-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (57 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Liverpool-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (57 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Liverpool Stats 2024-25 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/822bd0ba/2023-2024/Liverpool-Stats
#     ⏳ Cooling off 14.3s before next year...
#
# 🏆 Season 2024: https://fbref.com/en/squads/822bd0ba/2023-2024/Liverpool-Stats
#   📡 Requesting: Liverpool-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (58 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Liverpool-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (59 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Liverpool-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (59 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Liverpool-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (59 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Liverpool-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (59 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Liverpool Stats 2023-24 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/822bd0ba/2022-2023/Liverpool-Stats
#     ⏳ Cooling off 12.8s before next year...
# ✅ Completed Liverpool Stats. Cooling off 27.2s before next team...
#
#
# 🏃 Processing team 2/36: Manchester City Stats
#
# 🏆 Season 2026: https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats
#   📡 Requesting: Manchester-City-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (47 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Manchester-City-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (4 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Manchester-City-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (4 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Manchester-City-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (4 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Manchester-City-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (4 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Manchester City Stats 2025-26 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/b8fd03ef/2025/Manchester-City-Stats
#     ⏳ Cooling off 12.6s before next year...
#
# 🏆 Season 2025: https://fbref.com/en/squads/b8fd03ef/2025/Manchester-City-Stats
#   📡 Requesting: Manchester-City-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (4 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Manchester-City-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (5 rows)
#     📊 Getting Possession data...
#     ⚠️ No Possession links found
#     📊 Getting Goal/Shot Creation data...
#     ⚠️ No Goal/Shot Creation links found
#     📊 Getting Defense data...
#     ⚠️ No Defense links found
#     🔗 Starting merge with 18 base columns
#        + shooting (3 cols)
#     ✅ Finished Manchester City Stats 2024-25 → 23 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/b8fd03ef/2024-2025/Manchester-City-Stats
#     ⏳ Cooling off 17.9s before next year...
#
# 🏆 Season 2024: https://fbref.com/en/squads/b8fd03ef/2024-2025/Manchester-City-Stats
#   📡 Requesting: Manchester-City-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (57 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Manchester-City-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (58 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Manchester-City-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (58 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Manchester-City-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (58 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Manchester-City-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (58 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Manchester City Stats 2023-24 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/b8fd03ef/2023-2024/Manchester-City-Stats
#     ⏳ Cooling off 12.9s before next year...
# ✅ Completed Manchester City Stats. Cooling off 35.4s before next team...
#
#
# 🏃 Processing team 3/36: Newcastle United Stats
#
# 🏆 Season 2026: https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats
#   📡 Requesting: Newcastle-United-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (47 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Newcastle-United-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded
rows)
#     📊 Getting Defense data...
#   📡 Requesting: Paris-Saint-Germain-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (5 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Paris Saint Germain Stats 2025-26 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/e2d8892c/2025/Paris-Saint-Germain-Stats
#     ⏳ Cooling off 16.7s before next year...
#
# 🏆 Season 2025: https://fbref.com/en/squads/e2d8892c/2025/Paris-Saint-Germain-Stats
#   📡 Requesting: Paris-Saint-Germain-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (7 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Paris-Saint-Germain-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (8 rows)
#     📊 Getting Possession data...
#     ⚠️ No Possession links found
#     📊 Getting Goal/Shot Creation data...
#     ⚠️ No Goal/Shot Creation links found
#     📊 Getting Defense data...
#     ⚠️ No Defense links found
#     🔗 Starting merge with 18 base columns
#        + shooting (3 cols)
#     ✅ Finished Paris Saint Germain Stats 2024-25 → 23 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/e2d8892c/2024-2025/Paris-Saint-Germain-Stats
#     ⏳ Cooling off 14.6s before next year...
#
# 🏆 Season 2024: https://fbref.com/en/squads/e2d8892c/2024-2025/Paris-Saint-Germain-Stats
#   📡 Requesting: Paris-Saint-Germain-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (58 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Paris-Saint-Germain-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (59 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Paris-Saint-Germain-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (59 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Paris-Saint-Germain-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (59 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Paris-Saint-Germain-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (59 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Paris Saint Germain Stats 2023-24 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/e2d8892c/2023-2024/Paris-Saint-Germain-Stats
#     ⏳ Cooling off 11.4s before next year...
# ✅ Completed Paris Saint Germain Stats. Cooling off 38.7s before next team...
#
#
# 🏃 Processing team 12/36: Marseille Stats
#
# 🏆 Season 2026: https://fbref.com/en/squads/5725cc7b/Marseille-Stats
#   📡 Requesting: Marseille-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (42 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Marseille-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (4 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Marseille-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (4 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Marseille-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (4 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Marseille-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (4 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Marseille Stats 2025-26 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/5725cc7b/2024-2025/Marseille-Stats
#     ⏳ Cooling off 12.8s before next year...
#
# 🏆 Season 2025: https://fbref.com/en/squads/5725cc7b/2024-2025/Marseille-Stats
#   📡 Requesting: Marseille-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (36 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Marseille-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (37 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Marseille-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (37 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Marseille-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (37 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Marseille-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (37 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Marseille Stats 2024-25 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/5725cc7b/2023-2024/Marseille-Stats
#     ⏳ Cooling off 16.3s before next year...
#
# 🏆 Season 2024: https://fbref.com/en/squads/5725cc7b/2023-2024/Marseille-Stats
#   📡 Requesting: Marseille-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (52 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Marseille-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (53 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Marseille-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (53 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Marseille-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (53 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Marseille-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (53 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Marseille Stats 2023-24 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/5725cc7b/2022-2023/Marseille-Stats
#     ⏳ Cooling off 16.6s before next year...
# ✅ Completed Marseille Stats. Cooling off 23.8s before next team...
#
#
# 🏃 Processing team 13/36: Monaco Stats
#
# 🏆 Season 2026: https://fbref.com/en/squads/fd6114db/Monaco-Stats
#   📡 Requesting: Monaco-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (42 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Monaco-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (4 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Monaco-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (4 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Monaco-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (4 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Monaco-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (4 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Monaco Stats 2025-26 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/fd6114db/2024-2025/Monaco-Stats
#     ⏳ Cooling off 14.7s before next year...
#
# 🏆 Season 2025: https://fbref.com/en/squads/fd6114db/2024-2025/Monaco-Stats
#   📡 Requesting: Monaco-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (47 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Monaco-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (48 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Monaco-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (48 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Monaco-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (48 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Monaco-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (48 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Monaco Stats 2024-25 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/fd6114db/2023-2024/Monaco-Stats
#     ⏳ Cooling off 15.3s before next year...
#
# 🏆 Season 2024: https://fbref.com/en/squads/fd6114db/2023-2024/Monaco-Stats
#   📡 Requesting: Monaco-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (37 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Monaco-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (38 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Monaco-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (38 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Monaco-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (38 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Monaco-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (38 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Monaco Stats 2023-24 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/fd6114db/2022-2023/Monaco-Stats
#     ⏳ Cooling off 16.2s before next year...
# ✅ Completed Monaco Stats. Cooling off 35.5s before next team...
#
#
# 🏃 Processing team 14/36: Real Madrid Stats
#
# 🏆 Season 2026: https://fbref.com/en/squads/53a2f082/Real-Madrid-Stats
#   📡 Requesting: Real-Madrid-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (46 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Real-Madrid-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (4 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Real-Madrid-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (4 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Real-Madrid-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (4 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Real-Madrid-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (4 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Real Madrid Stats 2025-26 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/53a2f082/2025/Real-Madrid-Stats
#     ⏳ Cooling off 14.0s before next year...
#
# 🏆 Season 2025: https://fbref.com/en/squads/53a2f082/2025/Real-Madrid-Stats
#   📡 Requesting: Real-Madrid-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (6 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Real-Madrid-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (7 rows)
#     📊 Getting Possession data...
#     ⚠️ No Possession links found
#     📊 Getting Goal/Shot Creation data...
#     ⚠️ No Goal/Shot Creation links found
#     📊 Getting Defense data...
#     ⚠️ No Defense links found
#     🔗 Starting merge with 18 base columns
#        + shooting (3 cols)
#     ✅ Finished Real Madrid Stats 2024-25 → 23 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/53a2f082/2024-2025/Real-Madrid-Stats
#     ⏳ Cooling off 10.1s before next year...
#
# 🏆 Season 2024: https://fbref.com/en/squads/53a2f082/2024-2025/Real-Madrid-Stats
#   📡 Requesting: Real-Madrid-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (61 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Real-Madrid-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (62 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Real-Madrid-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (62 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Real-Madrid-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (62 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Real-Madrid-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (62 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Real Madrid Stats 2023-24 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/53a2f082/2023-2024/Real-Madrid-Stats
#     ⏳ Cooling off 17.6s before next year...
# ✅ Completed Real Madrid Stats. Cooling off 29.3s before next team...
#
#
# 🏃 Processing team 15/36: Barcelona Stats
#
# 🏆 Season 2026: https://fbref.com/en/squads/206d90db/Barcelona-Stats
#   📡 Requesting: Barcelona-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (46 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Barcelona-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (4 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Barcelona-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (4 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Barcelona-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (4 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Barcelona-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (4 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
# ...
#   ✅ Success!
#     📋 Matches found (47 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: FC-Copenhagen-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (48 rows)
#     📊 Getting Possession data...
#   📡 Requesting: FC-Copenhagen-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (48 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: FC-Copenhagen-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (48 rows)
#     📊 Getting Defense data...
#   📡 Requesting: FC-Copenhagen-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (48 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished FC Copenhagen Stats 2023-24 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/18050b20/2022-2023/FC-Copenhagen-Stats
#     ⏳ Cooling off 14.1s before next year...
# ✅ Completed FC Copenhagen Stats. Cooling off 35.5s before next team...
#
#
# 🏃 Processing team 32/36: Club Brugge Stats
#
# 🏆 Season 2026: https://fbref.com/en/squads/f1e6c5f1/Club-Brugge-Stats
#   📡 Requesting: Club-Brugge-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (42 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Club-Brugge-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (10 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Club-Brugge-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (10 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Club-Brugge-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (10 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Club-Brugge-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (10 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Club Brugge Stats 2025-26 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/f1e6c5f1/2024-2025/Club-Brugge-Stats
#     ⏳ Cooling off 17.2s before next year...
#
# 🏆 Season 2025: https://fbref.com/en/squads/f1e6c5f1/2024-2025/Club-Brugge-Stats
#   📡 Requesting: Club-Brugge-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (52 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Club-Brugge-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (53 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Club-Brugge-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (53 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Club-Brugge-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (53 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Club-Brugge-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (53 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Club Brugge Stats 2024-25 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/f1e6c5f1/2023-2024/Club-Brugge-Stats
#     ⏳ Cooling off 14.9s before next year...
#
# 🏆 Season 2024: https://fbref.com/en/squads/f1e6c5f1/2023-2024/Club-Brugge-Stats
#   📡 Requesting: Club-Brugge-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (58 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Club-Brugge-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (59 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Club-Brugge-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (59 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Club-Brugge-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (59 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Club-Brugge-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (59 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Club Brugge Stats 2023-24 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/f1e6c5f1/2022-2023/Club-Brugge-Stats
#     ⏳ Cooling off 15.8s before next year...
# ✅ Completed Club Brugge Stats. Cooling off 29.3s before next team...
#
#
# 🏃 Processing team 33/36: Pafos FC Stats
#
# 🏆 Season 2026: https://fbref.com/en/squads/cb42669e/Pafos-FC-Stats
#   📡 Requesting: Pafos-FC-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (14 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Pafos-FC-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (7 rows)
#     📊 Getting Possession data...
#     ⚠️ No Possession links found
#     📊 Getting Goal/Shot Creation data...
#     ⚠️ No Goal/Shot Creation links found
#     📊 Getting Defense data...
#     ⚠️ No Defense links found
#     🔗 Starting merge with 18 base columns
#        + shooting (3 cols)
#     ✅ Finished Pafos FC Stats 2025-26 → 23 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/cb42669e/2024-2025/Pafos-FC-Stats
#     ⏳ Cooling off 18.5s before next year...
#
# 🏆 Season 2025: https://fbref.com/en/squads/cb42669e/2024-2025/Pafos-FC-Stats
#   📡 Requesting: Pafos-FC-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (18 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Pafos-FC-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (19 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Pafos-FC-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (19 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Pafos-FC-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (19 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Pafos-FC-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (19 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Pafos FC Stats 2024-25 → 40 cols
# ❌ No previous season found — stopping loop
# ✅ Completed Pafos FC Stats. Cooling off 21.7s before next team...
#
#
# 🏃 Processing team 34/36: Qarabag Stats
#
# 🏆 Season 2026: https://fbref.com/en/squads/44b65410/Qarabag-Stats
#   📡 Requesting: Qarabag-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (14 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Qarabag-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (7 rows)
#     📊 Getting Possession data...
#     ⚠️ No Possession links found
#     📊 Getting Goal/Shot Creation data...
#     ⚠️ No Goal/Shot Creation links found
#     📊 Getting Defense data...
#     ⚠️ No Defense links found
#     🔗 Starting merge with 18 base columns
#        + shooting (3 cols)
#     ✅ Finished Qarabag Stats 2025-26 → 23 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/44b65410/2024-2025/Qarabag-Stats
#     ⏳ Cooling off 15.2s before next year...
#
# 🏆 Season 2025: https://fbref.com/en/squads/44b65410/2024-2025/Qarabag-Stats
#   📡 Requesting: Qarabag-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (14 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Qarabag-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (15 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Qarabag-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (15 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Qarabag-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (15 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Qarabag-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (15 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Qarabag Stats 2024-25 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/44b65410/2023-2024/Qarabag-Stats
#     ⏳ Cooling off 17.3s before next year...
#
# 🏆 Season 2024: https://fbref.com/en/squads/44b65410/2023-2024/Qarabag-Stats
#   📡 Requesting: Qarabag-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (18 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Qarabag-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (19 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Qarabag-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (19 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Qarabag-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (19 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Qarabag-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (19 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Qarabag Stats 2023-24 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/44b65410/2022-2023/Qarabag-Stats
#     ⏳ Cooling off 15.8s before next year...
# ✅ Completed Qarabag Stats. Cooling off 38.4s before next team...
#
#
# 🏃 Processing team 35/36: Qairat Almaty Stats
#
# 🏆 Season 2026: https://fbref.com/en/squads/768fb565/Qairat-Almaty-Stats
#   📡 Requesting: Qairat-Almaty-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (16 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Qairat-Almaty-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (9 rows)
#     📊 Getting Possession data...
#     ⚠️ No Possession links found
#     📊 Getting Goal/Shot Creation data...
#     ⚠️ No Goal/Shot Creation links found
#     📊 Getting Defense data...
#     ⚠️ No Defense links found
#     🔗 Starting merge with 18 base columns
#        + shooting (3 cols)
#     ✅ Finished Qairat Almaty Stats 2025-26 → 23 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/768fb565/2022-2023/Qairat-Almaty-Stats
#     ⏳ Cooling off 15.5s before next year...
#
# 🏆 Season 2025: https://fbref.com/en/squads/768fb565/2022-2023/Qairat-Almaty-Stats
#   📡 Requesting: Qairat-Almaty-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (2 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Qairat-Almaty-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (3 rows)
#     📊 Getting Possession data...
#     ⚠️ No Possession links found
#     📊 Getting Goal/Shot Creation data...
#     ⚠️ No Goal/Shot Creation links found
#     📊 Getting Defense data...
#     ⚠️ No Defense links found
#     🔗 Starting merge with 18 base columns
#        + shooting (3 cols)
#     ✅ Finished Qairat Almaty Stats 2024-25 → 23 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/768fb565/2021-2022/Qairat-Almaty-Stats
#     ⏳ Cooling off 14.1s before next year...
#
# 🏆 Season 2024: https://fbref.com/en/squads/768fb565/2021-2022/Qairat-Almaty-Stats
#   📡 Requesting: Qairat-Almaty-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (14 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Qairat-Almaty-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (15 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Qairat-Almaty-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (15 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Qairat-Almaty-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (15 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Qairat-Almaty-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (15 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Qairat Almaty Stats 2023-24 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/768fb565/2020-2021/Qairat-Almaty-Stats
#     ⏳ Cooling off 15.7s before next year...
# ✅ Completed Qairat Almaty Stats. Cooling off 25.1s before next team...
#
#
# 🏃 Processing team 36/36: Union SG Stats
#
# 🏆 Season 2026: https://fbref.com/en/squads/e14f61a5/Union-SG-Stats
#   📡 Requesting: Union-SG-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (38 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Union-SG-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (7 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Union-SG-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (7 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Union-SG-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (7 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Union-SG-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (7 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Union SG Stats 2025-26 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/e14f61a5/2024-2025/Union-SG-Stats
#     ⏳ Cooling off 12.2s before next year...
#
# 🏆 Season 2025: https://fbref.com/en/squads/e14f61a5/2024-2025/Union-SG-Stats
#   📡 Requesting: Union-SG-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (52 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Union-SG-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (53 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Union-SG-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Possession data loaded (53 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Union-SG-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (53 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Union-SG-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (53 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Union SG Stats 2024-25 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/e14f61a5/2023-2024/Union-SG-Stats
#     ⏳ Cooling off 12.4s before next year...
#
# 🏆 Season 2024: https://fbref.com/en/squads/e14f61a5/2023-2024/Union-SG-Stats
#   📡 Requesting: Union-SG-Stats (attempt 1/3)
#   ✅ Success!
#     📋 Matches found (52 rows)
#     📊 Getting Shooting data...
#   📡 Requesting: Union-SG-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Shooting data loaded (53 rows)
#     📊 Getting Possession data...
#   📡 Requesting: Union-SG-Match-Logs-All-Competitions (attempt 1/2)
#   💥 Request failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⏳ Waiting 5.1 seconds before retry...
#   📡 Requesting: Union-SG-Match-Logs-All-Competitions (attempt 2/2)
#   ✅ Success!
#     ✅ Possession data loaded (53 rows)
#     📊 Getting Goal/Shot Creation data...
#   📡 Requesting: Union-SG-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Goal/Shot Creation data loaded (53 rows)
#     📊 Getting Defense data...
#   📡 Requesting: Union-SG-Match-Logs-All-Competitions (attempt 1/2)
#   ✅ Success!
#     ✅ Defense data loaded (53 rows)
#     🔗 Starting merge with 20 base columns
#        + shooting (3 cols)
#        + poss (9 cols)
#        + gsc (2 cols)
#        + def (3 cols)
#     ✅ Finished Union SG Stats 2023-24 → 40 cols
# ➡️  Moving to previous season → https://fbref.com/en/squads/e14f61a5/2022-2023/Union-SG-Stats
#     ⏳ Cooling off 10.7s before next year...
# ✅ Completed Union SG Stats. Cooling off 20.4s before next team...

# %%
# More robust concatenation with error handling and duplicate column fix
if all_matches:
    # First, fix any duplicate columns in each DataFrame
    fixed_matches = []
    for i, df in enumerate(all_matches):
        # Remove duplicate columns by keeping only the first occurrence
        df_fixed = df.loc[:, ~df.columns.duplicated()]
        
        # Also ensure all column names are strings (sometimes they can be tuples)
        df_fixed.columns = [str(col) if not isinstance(col, str) else col for col in df_fixed.columns]
        
        fixed_matches.append(df_fixed)
        print(f"DataFrame {i}: {df.shape[1]} → {df_fixed.shape[1]} columns (removed {df.shape[1] - df_fixed.shape[1]} duplicates)")
    
    try:
        # First try normal concat with fixed DataFrames
        all_match_data = pd.concat(fixed_matches, ignore_index=True)
        print(f"\n🎉 Scraping complete! Total matches collected: {all_match_data.shape[0]}")
    except (ValueError, KeyError) as e:
        print(f"⚠️ Normal concat failed: {e}")
        print("Trying with outer join to handle column mismatches...")
        # Use outer join to handle different column structures
        all_match_data = pd.concat(fixed_matches, ignore_index=True, join='outer', sort=False)
        print(f"✅ Concatenation successful: {all_match_data.shape[0]} rows, {all_match_data.shape[1]} columns")
else:
    print("❌ No data collected")
    all_match_data = pd.DataFrame()
# Out:
# DataFrame 0: 40 → 39 columns (removed 1 duplicates)
# DataFrame 1: 40 → 39 columns (removed 1 duplicates)
# DataFrame 2: 40 → 39 columns (removed 1 duplicates)
# DataFrame 3: 40 → 39 columns (removed 1 duplicates)
# DataFrame 4: 23 → 23 columns (removed 0 duplicates)
# DataFrame 5: 40 → 39 columns (removed 1 duplicates)
# DataFrame 6: 40 → 39 columns (removed 1 duplicates)
# DataFrame 7: 40 → 39 columns (removed 1 duplicates)
# DataFrame 8: 40 → 39 columns (removed 1 duplicates)
# DataFrame 9: 40 → 39 columns (removed 1 duplicates)
# DataFrame 10: 40 → 39 columns (removed 1 duplicates)
# DataFrame 11: 40 → 39 columns (removed 1 duplicates)
# DataFrame 12: 40 → 39 columns (removed 1 duplicates)
# DataFrame 13: 23 → 23 columns (removed 0 duplicates)
# DataFrame 14: 40 → 39 columns (removed 1 duplicates)
# DataFrame 15: 40 → 39 columns (removed 1 duplicates)
# DataFrame 16: 40 → 39 columns (removed 1 duplicates)
# DataFrame 17: 40 → 39 columns (removed 1 duplicates)
# DataFrame 18: 40 → 39 columns (removed 1 duplicates)
# DataFrame 19: 40 → 39 columns (removed 1 duplicates)
# DataFrame 20: 40 → 39 columns (removed 1 duplicates)
# DataFrame 21: 40 → 39 columns (removed 1 duplicates)
# DataFrame 22: 23 → 23 columns (removed 0 duplicates)
# DataFrame 23: 40 → 39 columns (removed 1 duplicates)
# DataFrame 24: 40 → 39 columns (removed 1 duplicates)
# DataFrame 25: 23 → 23 columns (removed 0 duplicates)
# DataFrame 26: 40 → 39 columns (removed 1 duplicates)
# DataFrame 27: 40 → 39 columns (removed 1 duplicates)
# DataFrame 28: 40 → 39 columns (removed 1 duplicates)
# DataFrame 29: 40 → 39 columns (removed 1 duplicates)
# DataFrame 30: 40 → 39 columns (removed 1 duplicates)
# DataFrame 31: 23 → 23 columns (removed 0 duplicates)
# DataFrame 32: 40 → 39 columns (removed 1 duplicates)
# DataFrame 33: 40 → 39 columns (removed 1 duplicates)
# DataFrame 34: 40 → 39 columns (removed 1 duplicates)
# DataFrame 35: 40 → 39 columns (removed 1 duplicates)
# DataFrame 36: 40 → 39 columns (removed 1 duplicates)
# DataFrame 37: 40 → 39 columns (removed 1 duplicates)
# DataFrame 38: 40 → 39 columns (removed 1 duplicates)
# DataFrame 39: 40 → 39 columns (removed 1 duplicates)
# DataFrame 40: 23 → 23 columns (removed 0 duplicates)
# DataFrame 41: 40 → 39 columns (removed 1 duplicates)
# DataFrame 42: 40 → 39 columns (removed 1 duplicates)
# DataFrame 43: 40 → 39 columns (removed 1 duplicates)
# DataFrame 44: 40 → 39 columns (removed 1 duplicates)
# DataFrame 45: 40 → 39 columns (removed 1 duplicates)
# DataFrame 46: 23 → 23 columns (removed 0 duplicates)
# DataFrame 47: 40 → 39 columns (removed 1 duplicates)
# DataFrame 48: 40 → 39 columns (removed 1 duplicates)
# DataFrame 49: 40 → 39 columns (removed 1 duplicates)
# DataFrame 50: 40 → 39 columns (removed 1 duplicates)
# DataFrame 51: 40 → 39 columns (removed 1 duplicates)
# DataFrame 52: 40 → 39 columns (removed 1 duplicates)
# DataFrame 53: 40 → 39 columns (removed 1 duplicates)
# DataFrame 54: 40 → 39 columns (removed 1 duplicates)
# DataFrame 55: 23 → 23 columns (removed 0 duplicates)
# DataFrame 56: 40 → 39 columns (removed 1 duplicates)
# DataFrame 57: 40 → 39 columns (removed 1 duplicates)
# DataFrame 58: 40 → 39 columns (removed 1 duplicates)
# DataFrame 59: 40 → 39 columns (removed 1 duplicates)
# DataFrame 60: 40 → 39 columns (removed 1 duplicates)
# DataFrame 61: 23 → 23 columns (removed 0 duplicates)
# DataFrame 62: 40 → 39 columns (removed 1 duplicates)
# DataFrame 63: 40 → 39 columns (removed 1 duplicates)
# DataFrame 64: 40 → 39 columns (removed 1 duplicates)
# DataFrame 65: 40 → 39 columns (removed 1 duplicates)
# DataFrame 66: 40 → 39 columns (removed 1 duplicates)
# DataFrame 67: 40 → 39 columns (removed 1 duplicates)
# DataFrame 68: 40 → 39 columns (removed 1 duplicates)
# DataFrame 69: 40 → 39 columns (removed 1 duplicates)
# DataFrame 70: 40 → 39 columns (removed 1 duplicates)
# DataFrame 71: 40 → 39 columns (removed 1 duplicates)
# DataFrame 72: 23 → 23 columns (removed 0 duplicates)
# DataFrame 73: 40 → 39 columns (removed 1 duplicates)
# DataFrame 74: 40 → 39 columns (removed 1 duplicates)
# DataFrame 75: 23 → 23 columns (removed 0 duplicates)
# DataFrame 76: 40 → 39 columns (removed 1 duplicates)
# DataFrame 77: 40 → 39 columns (removed 1 duplicates)
# DataFrame 78: 23 → 23 columns (removed 0 duplicates)
# DataFrame 79: 23 → 23 columns (removed 0 duplicates)
# DataFrame 80: 40 → 39 columns (removed 1 duplicates)
# DataFrame 81: 40 → 39 columns (removed 1 duplicates)
# DataFrame 82: 23 → 23 columns (removed 0 duplicates)
# DataFrame 83: 40 → 39 columns (removed 1 duplicates)
# DataFrame 84: 40 → 39 columns (removed 1 duplicates)
# DataFrame 85: 40 → 39 columns (removed 1 duplicates)
# DataFrame 86: 40 → 39 columns (removed 1 duplicates)
# DataFrame 87: 23 → 23 columns (removed 0 duplicates)
# DataFrame 88: 40 → 39 columns (removed 1 duplicates)
# DataFrame 89: 40 → 39 columns (removed 1 duplicates)
# DataFrame 90: 23 → 23 columns (removed 0 duplicates)
# DataFrame 91: 40 → 39 columns (removed 1 duplicates)
# DataFrame 92: 40 → 39 columns (removed 1 duplicates)
# DataFrame 93: 40 → 39 columns (removed 1 duplicates)
# DataFrame 94: 40 → 39 columns (removed 1 duplicates)
# DataFrame 95: 40 → 39 columns (removed 1 duplicates)
# DataFrame 96: 23 → 23 columns (removed 0 duplicates)
# DataFrame 97: 40 → 39 columns (removed 1 duplicates)
# DataFrame 98: 23 → 23 columns (removed 0 duplicates)
# DataFrame 99: 40 → 39 columns (removed 1 duplicates)
# DataFrame 100: 40 → 39 columns (removed 1 duplicates)
# DataFrame 101: 23 → 23 columns (removed 0 duplicates)
# DataFrame 102: 23 → 23 columns (removed 0 duplicates)
# DataFrame 103: 40 → 39 columns (removed 1 duplicates)
# DataFrame 104: 40 → 39 columns (removed 1 duplicates)
# DataFrame 105: 40 → 39 columns (removed 1 duplicates)
# DataFrame 106: 40 → 39 columns (removed 1 duplicates)
#
# 🎉 Scraping complete! Total matches collected: 4344

# %%
all_match_data
# Out:
#             Date   Time                 Comp                Round  Day  \
# 0     2025-08-10  15:00  FA Community Shield  FA Community Shield  Sun
# 1     2025-08-15  20:00       Premier League          Matchweek 1  Fri
# 2     2025-08-25  20:00       Premier League          Matchweek 2  Mon
# 3     2025-08-31  16:30       Premier League          Matchweek 3  Sun
# 4     2025-09-14  14:00       Premier League          Matchweek 4  Sun
# ...          ...    ...                  ...                  ...  ...
# 4339  2024-04-28  18:30         Pro League A  Champions play-offs  Sun
# 4340  2024-05-05  18:30         Pro League A  Champions play-offs  Sun
# 4341  2024-05-13  20:30         Pro League A  Champions play-offs  Mon
# 4342  2024-05-19  13:30         Pro League A  Champions play-offs  Sun
# 4343  2024-05-26  18:30         Pro League A  Champions play-offs  Sun
#
#         Venue Result     GF     GA        Opponent  ...  Succ%_poss  \
# 0     Neutral      D  2 (2)  2 (3)  Crystal Palace  ...         NaN
# 1        Home      W      4      2     Bournemouth  ...        38.1
# 2        Away      W      3      2   Newcastle Utd  ...        50.0
# 3        Home      W      1      0         Arsenal  ...        46.7
# 4        Away    NaN    NaN    NaN         Burnley  ...         NaN
# ...       ...    ...    ...    ...             ...  ...         ...
# 4339     Home      W      4      1         Antwerp  ...        57.9
# 4340     Home      D      0      0      Anderlecht  ...        18.2
# 4341     Away      D      2      2     Club Brugge  ...        46.7
# 4342     Away      W      2      1   Cercle Brugge  ...        61.1
# 4343     Home      W      2      0            Genk  ...        36.8
#
#       PrgDist_poss  1/3_poss  SCA_gsc PassLive_gsc Tkl+Int_def TklW_def  \
# 0              NaN       NaN      NaN          NaN         0.0      8.0
# 1            914.0      14.0     36.0         32.0        20.0     13.0
# 2            787.0       8.0      9.0          8.0        15.0      8.0
# 3            939.0       8.0     16.0         13.0        18.0      9.0
# 4              NaN       NaN      NaN          NaN         NaN      NaN
# ...            ...       ...      ...          ...         ...      ...
# 4339        1192.0      28.0     22.0         20.0        30.0     17.0
# 4340        1034.0      13.0     30.0         24.0        22.0     10.0
# 4341         743.0      14.0     28.0         23.0        30.0     13.0
# 4342         495.0      10.0     26.0         17.0        26.0     10.0
# 4343         952.0      16.0     37.0         31.0        46.0     17.0
#
#      Tkl%_def             Team   Season
# 0         NaN  Liverpool Stats  2025-26
# 1        57.9  Liverpool Stats  2025-26
# 2        52.9  Liverpool Stats  2025-26
# 3        62.5  Liverpool Stats  2025-26
# 4         NaN  Liverpool Stats  2025-26
# ...       ...              ...      ...
# 4339     68.8   Union SG Stats  2023-24
# 4340     62.5   Union SG Stats  2023-24
# 4341     47.6   Union SG Stats  2023-24
# 4342     55.0   Union SG Stats  2023-24
# 4343     65.5   Union SG Stats  2023-24
#
# [4344 rows x 39 columns]

# %%
all_match_data.to_csv("champions_league_match_stats.csv", index=False)
