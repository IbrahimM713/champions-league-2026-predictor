# %%
import cloudscraper
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
# Pulling the HTML data from the link
scraper = cloudscraper.create_scraper()
url = "https://fbref.com/en/comps/8/Champions-League-Stats"

# %%
# Getting the HTML only from the standings table

resp = scraper.get(url)   # no verify=False needed
soup = BeautifulSoup(resp.text, "html.parser")
standings_table = soup.select("table.stats_table")[0]

# %%
# Finding all of the a tags within the table, which contains the link to more data for each team
links = standings_table.find_all("a")
# Extracting the href properties from the links
links = [link.get("href") for link in links]
# Filtering the links to only include those that contain "/squads/", which is the pattern for team data pages
links = [l for l in links if l and "/squads/" in l]
# Constructing the full URLs for each team
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
data = scraper.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"

# %%
team_urls
# Out:
# ['https://fbref.com/en/squads/822bd0ba/Liverpool-Stats',
#  'https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats',
#  'https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats',
#  'https://fbref.com/en/squads/18bb7c10/Arsenal-Stats',
#  'https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats',
#  'https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  'https://fbref.com/en/squads/f0ac8ee6/Eintracht-Frankfurt-Stats',
#  'https://fbref.com/en/squads/add600ae/Dortmund-Stats',
#  'https://fbref.com/en/squads/054efa67/Bayern-Munich-Stats',
#  'https://fbref.com/en/squads/c7a9f859/Bayer-Leverkusen-Stats',
#  'https://fbref.com/en/squads/e2d8892c/Paris-Saint-Germain-Stats',
#  'https://fbref.com/en/squads/5725cc7b/Marseille-Stats',
#  'https://fbref.com/en/squads/fd6114db/Monaco-Stats',
#  'https://fbref.com/en/squads/53a2f082/Real-Madrid-Stats',
#  'https://fbref.com/en/squads/206d90db/Barcelona-Stats',
#  'https://fbref.com/en/squads/db3b9613/Atletico-Madrid-Stats',
# ...

# %%
from io import StringIO
MC_url = team_urls[1]  # Example: Manchester City URL
data = scraper.get(MC_url)

matches = pd.read_html(StringIO(data.text), match="Scores & Fixtures")


matches[0]
# Out:
#           Date   Time            Comp         Round  Day Venue Result   GF  \
# 0   2025-08-16  17:30  Premier League   Matchweek 1  Sat  Away      W  4.0
# 1   2025-08-23  12:30  Premier League   Matchweek 2  Sat  Home      L  0.0
# 2   2025-08-31  14:00  Premier League   Matchweek 3  Sun  Away      L  1.0
# 3   2025-09-14  16:30  Premier League   Matchweek 4  Sun  Home    NaN  NaN
# 4   2025-09-18  20:00    Champions Lg  League phase  Thu  Home    NaN  NaN
# 5   2025-09-21  16:30  Premier League   Matchweek 5  Sun  Away    NaN  NaN
# 6   2025-09-24  19:45         EFL Cup   Third round  Wed  Away    NaN  NaN
# 7   2025-09-27  15:00  Premier League   Matchweek 6  Sat  Home    NaN  NaN
# 8   2025-10-01  21:00    Champions Lg  League phase  Wed  Away    NaN  NaN
# 9   2025-10-05  16:30  Premier League   Matchweek 7  Sun  Away    NaN  NaN
# 10  2025-10-18  15:00  Premier League   Matchweek 8  Sat  Home    NaN  NaN
# ...

# %%
# Pulling all the data related to shooting
soup2 = BeautifulSoup(data.text)
page_links = soup2.find_all("a")
page_links = [link.get("href") for link in page_links]
page_links = [l for l in page_links if l and "all_comps/shooting/" in l]

page_links
# Out:
# ['/en/squads/b8fd03ef/2025-2026/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2025-2026/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2025-2026/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2025-2026/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions']

# %%
# Using the web scraper to scrape the data from the shooting page link
data = scraper.get(f"https://fbref.com{page_links[0]}")
shooting = pd.read_html(StringIO(data.text), match="Shooting")[0]
# Dropping the first row of headers
shooting.columns = shooting.columns.droplevel()
shooting
# Out:
#          Date   Time            Comp        Round  Day Venue Result   GF   GA  \
# 0  2025-08-16  17:30  Premier League  Matchweek 1  Sat  Away      W  4.0  0.0
# 1  2025-08-23  12:30  Premier League  Matchweek 2  Sat  Home      L  0.0  2.0
# 2  2025-08-31  14:00  Premier League  Matchweek 3  Sun  Away      L  1.0  2.0
# 3         NaN    NaN             NaN          NaN  NaN   NaN     --  NaN  NaN
#
#     Opponent  ...  Dist  FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  np:G-xG  \
# 0     Wolves  ...  17.2   1   0      0  2.4   2.4     0.16   1.6      1.6
# 1  Tottenham  ...  16.3   0   0      0  1.6   1.6     0.16  -1.6     -1.6
# 2   Brighton  ...  15.1   0   0      0  1.8   1.8     0.15  -0.8     -0.8
# 3        NaN  ...  16.2   1   0      0  NaN   NaN     0.16   5.0      5.0
#
#    Match Report
# 0  Match Report
# 1  Match Report
# 2  Match Report
# 3           NaN
#
# [4 rows x 26 columns]

# %%
team_data = matches[0].merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")

team_data
# Out:
#          Date   Time            Comp        Round  Day Venue Result   GF   GA  \
# 0  2025-08-16  17:30  Premier League  Matchweek 1  Sat  Away      W  4.0  0.0
# 1  2025-08-23  12:30  Premier League  Matchweek 2  Sat  Home      L  0.0  2.0
# 2  2025-08-31  14:00  Premier League  Matchweek 3  Sun  Away      L  1.0  2.0
#
#     Opponent  ...  Opp Formation         Referee  Match Report  Notes  Sh SoT  \
# 0     Wolves  ...          3-4-3  Jarred Gillett  Match Report    NaN  15   4
# 1  Tottenham  ...          4-3-3    Peter Bankes  Match Report    NaN  10   4
# 2   Brighton  ...        4-2-3-1  Darren England  Match Report    NaN  12   3
#
#    Dist FK PK  PKatt
# 0  17.2  1  0      0
# 1  16.3  0  0      0
# 2  15.1  0  0      0
#
# [3 rows x 26 columns]

# %%
# Selecting which years to pull data from
years = list(range(2026, 2023, -1))
years
# Out:
# [2026, 2025, 2024]

# %%
all_matches = []
standings_url = "https://fbref.com/en/comps/8/Champions-League-Stats"

# %%
for year in years:
    # Doing the same steps as before to scrape the links for each team
    # Pulling the HTML data from the link
    data = scraper.get(standings_url)
    # Getting the HTML only from the standings table
    soup = BeautifulSoup(data.text)
    standings_table = soup.select("table.stats_table")[0]

    # Finding all of the a tags within the table, which contains the link to more data for each team
    links = standings_table.find_all("a")
    # Extracting the href properties from the links
    links = [link.get("href") for link in links]
    # Filtering the links to only include those that contain "/squads/", which is the pattern for team data pages
    links = [l for l in links if l and "/squads/" in l]
    # Constructing the full URLs for each team
    team_urls = [f"https://fbref.com{l}" for l in links]

    # Scraping the "previous season" button" by findings its href
    previous_season= soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"

    for team_url in team_urls:
        # Changing the Team name from the url to a readable format (From "Manchester-City-Stats" to "Manchester City")
        team_name = team_url.split("/")[-1].replace("-", " ").replace("_Stats", "")

        data = scraper.get(team_url)
        matches = pd.read_html(StringIO(data.text), match="Scores & Fixtures")

        # Pulling all the data related to shooting
        # Same steps as before to get link 
        soup = BeautifulSoup(data.text)
        page_links = soup.find_all("a")
        page_links = [link.get("href") for link in page_links]
        page_links = [l for l in page_links if l and "all_comps/shooting/" in l]

        data = scraper.get(f"https://fbref.com{page_links[0]}")
        shooting = pd.read_html(StringIO(data.text), match="Shooting")[0]
        # Dropping the first row of headers (there is initially two rows of eaders in "shooting")
        shooting.columns = shooting.columns.droplevel()

        # Trying to merge the team match and shooting stats. If there is not shooting stats, it skips those values and states what team and year it skipped
        try:
            team_data = matches[0].merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
            team_data["Team"] = team_name
            team_data["Season"] = f"{year-1}-{str(year)[-2:]}"
            all_matches.append(team_data)
        except ValueError:
            print(f"Skipping {team_name} for season {year-1}-{str(year)[-2:]} due to merge error.")
            continue

            # Adding the team name and season year to the dataframe to ensure we kn ow which team the result is for
        team_data["Season"] = year
        team_data["Team"] = team_name

        all_matches.append(team_data)
        time.sleep(1)  # Be polite and avoid overwhelming the server
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 7
#       5 # Getting the HTML only from the standings table
#       6 soup = BeautifulSoup(data.text)
# ----> 7 standings_table = soup.select("table.stats_table")[0]
#       9 # Finding all of the a tags within the table, which contains the link to more data for each team
#      10 links = standings_table.find_all("a")
#
# IndexError: list index out of range

# %%
match_df = pd.concat(all_matches)

# %%
soup = BeautifulSoup(data.text)
page_links = soup.find_all("a")
page_links = [link.get("href") for link in page_links]
page_links = [l for l in page_links if l and "all_comps/possession/" in l]
data = scraper.get(f"https://fbref.com{page_links[0]}")
possession = pd.read_html(StringIO(data.text), match="Possession")[0]
# Dropping the first row of headers (there is initially two rows of eaders in "possession")
possession.columns = possession.columns.droplevel()

possession
# Out:
#          Date   Time            Comp        Round  Day Venue Result   GF   GA  \
# 0  2025-08-16  17:30  Premier League  Matchweek 1  Sat  Away      W  4.0  0.0
# 1  2025-08-23  12:30  Premier League  Matchweek 2  Sat  Home      L  0.0  2.0
# 2  2025-08-31  14:00  Premier League  Matchweek 3  Sun  Away      L  1.0  2.0
# 3         NaN    NaN             NaN          NaN  NaN   NaN     --  NaN  NaN
#
#     Opponent  ...  TotDist  PrgDist  PrgC  1/3  CPA  Mis  Dis   Rec  PrgR  \
# 0     Wolves  ...     2375     1141    25   15    4   15   14   531    51
# 1  Tottenham  ...     1980      955    22   13   11   19   16   485    44
# 2   Brighton  ...     2261     1125    25   17    7   12    8   506    42
# 3        NaN  ...     6616     3221    72   45   22   46   38  1522   137
#
#    Match Report
# 0  Match Report
# 1  Match Report
# 2  Match Report
# 3           NaN
#
# [4 rows x 34 columns]

# %%
soup = BeautifulSoup(data.text)
page_links = soup.find_all("a")
page_links = [link.get("href") for link in page_links]
page_links = [l for l in page_links if l and "all_comps/gca" in l]
data = scraper.get(f"https://fbref.com{page_links[0]}")
goal_shot_creation = pd.read_html(StringIO(data.text), match="Goal and Shot Creation")[0]
# Dropping the first row of headers (there is initially two rows of eaders in "goal_shot_creation")
goal_shot_creation.columns = goal_shot_creation.columns.droplevel()

goal_shot_creation
# Out:
#          Date   Time            Comp        Round  Day Venue Result   GF   GA  \
# 0  2025-08-16  17:30  Premier League  Matchweek 1  Sat  Away      W  4.0  0.0
# 1  2025-08-23  12:30  Premier League  Matchweek 2  Sat  Home      L  0.0  2.0
# 2  2025-08-31  14:00  Premier League  Matchweek 3  Sun  Away      L  1.0  2.0
# 3         NaN    NaN             NaN          NaN  NaN   NaN     --  NaN  NaN
#
#     Opponent  ...  Fld  Def  GCA  PassLive  PassDead  TO  Sh  Fld  Def  \
# 0     Wolves  ...    1    0    8         7         0   1   0    0    0
# 1  Tottenham  ...    1    0    0         0         0   0   0    0    0
# 2   Brighton  ...    0    0    2         1         0   1   0    0    0
# 3        NaN  ...    2    0   10         8         0   2   0    0    0
#
#    Match Report
# 0  Match Report
# 1  Match Report
# 2  Match Report
# 3           NaN
#
# [4 rows x 25 columns]

# %%
soup = BeautifulSoup(data.text)
page_links = soup.find_all("a")
page_links = [link.get("href") for link in page_links]
page_links = [l for l in page_links if l and "all_comps/defense" in l]
data = scraper.get(f"https://fbref.com{page_links[0]}")
defense = pd.read_html(StringIO(data.text), match="Defensive Actions")[0]
# Dropping the first row of headers (there is initially two rows of eaders in "defense")
defense.columns = defense.columns.droplevel()

defense
# Out:
#          Date   Time            Comp        Round  Day Venue Result   GF   GA  \
# 0  2025-08-16  17:30  Premier League  Matchweek 1  Sat  Away      W  4.0  0.0
# 1  2025-08-23  12:30  Premier League  Matchweek 2  Sat  Home      L  0.0  2.0
# 2  2025-08-31  14:00  Premier League  Matchweek 3  Sun  Away      L  1.0  2.0
# 3         NaN    NaN             NaN          NaN  NaN   NaN     --  NaN  NaN
#
#     Opponent  ...  Tkl%  Lost  Blocks  Sh  Pass  Int  Tkl+Int  Clr  Err  \
# 0     Wolves  ...  44.4     5       9   3     6    7       25   24    2
# 1  Tottenham  ...  65.2     8       8   2     6    6       26   23    2
# 2   Brighton  ...  42.9     8      11   2     9    9       24   15    0
# 3        NaN  ...  54.3    21      28   7    21   22       75   62    4
#
#    Match Report
# 0  Match Report
# 1  Match Report
# 2  Match Report
# 3           NaN
#
# [4 rows x 27 columns]

# %%
team_data = matches[0].merge(shooting[["Date", "Sh", "SoT", "Dist"]], on="Date")
team_data = team_data.merge(possession[["Date", "Touches", "Def Pen", "Def 3rd", "Mid 3rd", "Att 3rd", "Att Pen", "Succ%", "PrgDist", "1/3"]], on="Date")
team_data = team_data.merge(goal_shot_creation[["Date", "SCA", "PassLive"]], on="Date")
team_data = team_data.merge(defense[["Date", "Tkl+Int", "TklW", "Tkl%"]], on="Date")

team_data
# Out:
#          Date   Time            Comp        Round  Day Venue Result   GF   GA  \
# 0  2025-08-16  17:30  Premier League  Matchweek 1  Sat  Away      W  4.0  0.0
# 1  2025-08-23  12:30  Premier League  Matchweek 2  Sat  Home      L  0.0  2.0
# 2  2025-08-31  14:00  Premier League  Matchweek 3  Sun  Away      L  1.0  2.0
#
#     Opponent  ...  Att Pen  Succ%  PrgDist  1/3 SCA PassLive PassLive Tkl+Int  \
# 0     Wolves  ...       26   50.0     1141   15  25       19        7      25
# 1  Tottenham  ...       32   41.2      955   13  18       14        0      26
# 2   Brighton  ...       21   48.3     1125   17  21       17        1      24
#
#   TklW  Tkl%
# 0   11  44.4
# 1   10  65.2
# 2    7  42.9
#
# [3 rows x 38 columns]
