# %%
import pandas as pd

matches_past = pd.read_csv("matches_past_elo.csv")
matches_future = pd.read_csv("matches_future_elo.csv")

# %%
# Adding a flag for if the team is playing at home or away
matches_past["is_home"] = matches_past["Venue"].astype("category").cat.codes
matches_future["is_home"] = matches_future["Venue"].astype("category").cat.codes

# Extracting hour and day of week from date and time
matches_past["Hour"] = matches_past["Time"].str.replace(r":.+", "", regex=True).fillna(0).astype(int)
matches_future["Hour"] = matches_future["Time"].str.replace(r":.+", "", regex=True).fillna(0).astype(int)

matches_past["DayOfWeek"] = pd.to_datetime(matches_past["Date"]).dt.dayofweek
matches_future["DayOfWeek"] = pd.to_datetime(matches_future["Date"]).dt.dayofweek

# %% [markdown]
# ### Calculating the Rolling Mean of Key Stats
#
# Calculating the rolling mean allows team form to be a factor in determining performance. I will use the form from the last 3 games for the key stats

# %%
def rolling_averages(group, cols, new_cols, window=3):
    group = group.sort_values("Date")
    # Compute rolling averages for the past N games (excluding current)
    rolling_stats = group[cols].rolling(window, closed="left", min_periods=1).mean()
    group[new_cols] = rolling_stats
    return group

# %%
cols = [
    "xG", "xGA", "Poss", "Sh_shooting", "SoT_shooting", "Dist_shooting",
    "Touches_poss", "Def Pen_poss", "Def 3rd_poss", "Mid 3rd_poss", 
    "Att 3rd_poss", "Att Pen_poss", "Succ%_poss", "PrgDist_poss", "1/3_poss",
    "SCA_gsc", "PassLive_gsc", "Tkl+Int_def", "TklW_def", "Tkl%_def"
]

new_cols = [f"avg_{c}" for c in cols]

# %%
# Computing a rolling average for every match in the df
matches_past = matches_past.groupby("Team").apply(lambda x: rolling_averages(x, cols, new_cols, window=3))
# Dropping the team level index created by groupby, as there would be two indexes
matches_past = matches_past.droplevel("Team")

#Re-indexing our data
matches_past.index = range(matches_past.shape[0]) 

# Forward fill per team, then fill any leftover with global mean. This is to account for teams that have not played 3 games yet, or do not have data available

matches_past[new_cols] = (
    matches_past.groupby("Team")[new_cols]
    .transform(lambda g: g.ffill())
    .fillna(matches_past[new_cols].mean())
)

# Adding opponent rolling averages
opp_cols = [f"opp_{c}" for c in new_cols]

# For each match, get opponent's rolling averages at that point in time
for idx, row in matches_past.iterrows():
    opponent = row["Opponent"]
    match_date = row["Date"]
    
    # Find opponent's most recent match before this one
    opponent_recent = matches_past[
        (matches_past["Team"] == opponent) & 
        (matches_past["Date"] < match_date)
    ].sort_values("Date").tail(1)
    
    if len(opponent_recent) > 0:
        # Use opponent's rolling averages
        for new_col, opp_col in zip(new_cols, opp_cols):
            matches_past.at[idx, opp_col] = opponent_recent[new_col].iloc[0]
    else:
        # If no previous matches, use global mean
        for new_col, opp_col in zip(new_cols, opp_cols):
            matches_past.at[idx, opp_col] = matches_past[new_col].mean()

matches_past
# Out:
# /var/folders/x7/sl4zn7qx64s6wq122_6jw9_00000gn/T/ipykernel_80180/2837806767.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_past = matches_past.groupby("Team").apply(lambda x: rolling_averages(x, cols, new_cols, window=3))
#             Date   Time        Comp           Round  Day Venue Result   GF  \
# 0     2023-08-12  20:00  Eredivisie     Matchweek 1  Sat  Home      W    4
# 1     2023-08-19  16:30  Eredivisie     Matchweek 2  Sat  Away      D    2
# 2     2023-08-24  21:00   Europa Lg  Play-off round  Thu  Away      W    4
# 3     2023-08-31  20:00   Europa Lg  Play-off round  Thu  Home      L    0
# 4     2023-09-03  14:30  Eredivisie     Matchweek 4  Sun  Away      D    0
# ...          ...    ...         ...             ...  ...   ...    ...  ...
# 2785  2025-05-18  19:00     La Liga    Matchweek 37  Sun  Away      W    3
# 2786  2025-05-25  16:15     La Liga    Matchweek 38  Sun  Home      W    4
# 2787  2025-08-15  21:30     La Liga     Matchweek 1  Fri  Home      W  2.0
# 2788  2025-08-24  19:30     La Liga     Matchweek 2  Sun  Home      W  5.0
# 2789  2025-08-31  17:00     La Liga     Matchweek 3  Sun  Away      D  1.0
#
#        GA         Opponent  ...  opp_avg_Att 3rd_poss  opp_avg_Att Pen_poss  \
# 0       1  Heracles Almelo  ...            175.683238             27.901740
# 1       2        Excelsior  ...            175.683238             27.901740
# 2       1       Ludogorets  ...            175.683238             27.901740
# 3       1       Ludogorets  ...            175.683238             27.901740
# 4       0  Fortuna Sittard  ...            175.683238             27.901740
# ...   ...              ...  ...                   ...                   ...
# 2785    2        Barcelona  ...            291.333333             39.333333
# 2786    2          Sevilla  ...            175.683238             27.901740
# 2787  0.0           Oviedo  ...            175.683238             27.901740
# 2788  0.0           Girona  ...            175.683238             27.901740
# 2789  1.0       Celta Vigo  ...            175.683238             27.901740
#
#       opp_avg_Succ%_poss  opp_avg_PrgDist_poss opp_avg_1/3_poss  \
# 0              44.678598           1082.985077         15.16662
# 1              44.678598           1082.985077         15.16662
# 2              44.678598           1082.985077         15.16662
# 3              44.678598           1082.985077         15.16662
# 4              44.678598           1082.985077         15.16662
# ...                  ...                   ...              ...
# 2785           48.333333           1493.000000         28.00000
# 2786           44.678598           1082.985077         15.16662
# 2787           44.678598           1082.985077         15.16662
# 2788           44.678598           1082.985077         15.16662
# 2789           44.678598           1082.985077         15.16662
#
#      opp_avg_SCA_gsc opp_avg_PassLive_gsc opp_avg_Tkl+Int_def  \
# 0          26.691413            19.978226           20.949043
# 1          26.691413            19.978226           20.949043
# 2          26.691413            19.978226           20.949043
# 3          26.691413            19.978226           20.949043
# 4          26.691413            19.978226           20.949043
# ...              ...                  ...                 ...
# 2785       42.333333            33.666667           23.000000
# 2786       26.691413            19.978226           20.949043
# 2787       26.691413            19.978226           20.949043
# 2788       26.691413            19.978226           20.949043
# 2789       26.691413            19.978226           20.949043
#
#      opp_avg_TklW_def opp_avg_Tkl%_def
# 0           10.089485        51.678302
# 1           10.089485        51.678302
# 2           10.089485        51.678302
# 3           10.089485        51.678302
# 4           10.089485        51.678302
# ...               ...              ...
# 2785         6.666667        55.100000
# 2786        10.089485        51.678302
# 2787        10.089485        51.678302
# 2788        10.089485        51.678302
# 2789        10.089485        51.678302
#
# [2790 rows x 96 columns]

# %% [markdown]
# ### Implementing the most recent rolling stats into the matches_future dataset

# %%
# Adding the most recent rolling stats to the matches_future dataset
latest_stats = (
    matches_past.sort_values("Date")
    .groupby("Team")
    .tail(1)[["Team"] + new_cols]
    .set_index("Team")
)

matches_future = matches_future.merge(
    latest_stats, left_on="Team", right_index=True, how="left"
)

# Adding opponent rolling averages to future matches
matches_future = matches_future.merge(
    latest_stats.add_prefix("opp_"), left_on="Opponent", right_index=True, how="left"
)

matches_future[matches_future["Team"] == "Real Madrid"]
# Out:
#             Date   Time          Comp         Round  Day Venue  Result  GF  \
# 14    2025-09-13  16:15       La Liga   Matchweek 4  Sat  Away     NaN NaN
# 42    2025-09-16  21:00  Champions Lg  League phase  Tue  Home     NaN NaN
# 76    2025-09-20  16:15       La Liga   Matchweek 5  Sat  Home     NaN NaN
# 105   2025-09-23  21:30       La Liga   Matchweek 6  Tue  Away     NaN NaN
# 124   2025-09-27  16:15       La Liga   Matchweek 7  Sat  Away     NaN NaN
# 150   2025-09-30  21:45  Champions Lg  League phase  Tue  Away     NaN NaN
# 180   2025-10-04  21:00       La Liga   Matchweek 8  Sat  Home     NaN NaN
# 233   2025-10-19  21:00       La Liga   Matchweek 9  Sun  Away     NaN NaN
# 260   2025-10-22  21:00  Champions Lg  League phase  Wed  Home     NaN NaN
# 294   2025-10-26    NaN       La Liga  Matchweek 10  Sun  Home     NaN NaN
# 349   2025-11-02    NaN       La Liga  Matchweek 11  Sun  Home     NaN NaN
# 355   2025-11-04  20:00  Champions Lg  League phase  Tue  Away     NaN NaN
# 406   2025-11-09    NaN       La Liga  Matchweek 12  Sun  Away     NaN NaN
# 440   2025-11-23    NaN       La Liga  Matchweek 13  Sun  Away     NaN NaN
# 470   2025-11-26  22:00  Champions Lg  League phase  Wed  Away     NaN NaN
# 499   2025-11-30    NaN       La Liga  Matchweek 14  Sun  Away     NaN NaN
# 557   2025-12-07    NaN       La Liga  Matchweek 15  Sun  Home     NaN NaN
# 585   2025-12-10  21:00  Champions Lg  League phase  Wed  Home     NaN NaN
# 607   2025-12-14    NaN       La Liga  Matchweek 16  Sun  Away     NaN NaN
# 648   2025-12-21    NaN       La Liga  Matchweek 17  Sun  Home     NaN NaN
# 690   2026-01-04    NaN       La Liga  Matchweek 18  Sun  Home     NaN NaN
# 714   2026-01-11    NaN       La Liga  Matchweek 19  Sun  Away     NaN NaN
# 743   2026-01-18    NaN       La Liga  Matchweek 20  Sun  Home     NaN NaN
# 759   2026-01-20  21:00  Champions Lg  League phase  Tue  Home     NaN NaN
# 804   2026-01-25    NaN       La Liga  Matchweek 21  Sun  Away     NaN NaN
# 844   2026-01-28  20:00  Champions Lg  League phase  Wed  Away     NaN NaN
# 882   2026-02-01    NaN       La Liga  Matchweek 22  Sun  Home     NaN NaN
# 909   2026-02-08    NaN       La Liga  Matchweek 23  Sun  Away     NaN NaN
# 933   2026-02-15    NaN       La Liga  Matchweek 24  Sun  Home     NaN NaN
# 965   2026-02-22    NaN       La Liga  Matchweek 25  Sun  Away     NaN NaN
# 998   2026-03-01    NaN       La Liga  Matchweek 26  Sun  Home     NaN NaN
# 1042  2026-03-08    NaN       La Liga  Matchweek 27  Sun  Away     NaN NaN
# 1060  2026-03-15    NaN       La Liga  Matchweek 28  Sun  Home     NaN NaN
# 1099  2026-03-22    NaN       La Liga  Matchweek 29  Sun  Home     NaN NaN
# 1126  2026-04-05    NaN       La Liga  Matchweek 30  Sun  Away     NaN NaN
# 1149  2026-04-12    NaN       La Liga  Matchweek 31  Sun  Home     NaN NaN
# 1176  2026-04-19    NaN       La Liga  Matchweek 32  Sun  Away     NaN NaN
# 1182  2026-04-22    NaN       La Liga  Matchweek 33  Wed  Home     NaN NaN
# 1225  2026-05-03    NaN       La Liga  Matchweek 34  Sun  Away     NaN NaN
# 1249  2026-05-10    NaN       La Liga  Matchweek 35  Sun  Away     NaN NaN
# 1263  2026-05-13    NaN       La Liga  Matchweek 36  Wed  Home     NaN NaN
# 1277  2026-05-17    NaN       La Liga  Matchweek 37  Sun  Away     NaN NaN
# 1298  2026-05-24    NaN       La Liga  Matchweek 38  Sun  Home     NaN NaN
#
#       GA         Opponent  ...  opp_avg_Att 3rd_poss  opp_avg_Att Pen_poss  \
# 14   NaN    Real Sociedad  ...                   NaN                   NaN
# 42   NaN        Marseille  ...            193.333333             28.333333
# 76   NaN         Espanyol  ...                   NaN                   NaN
# 105  NaN          Levante  ...                   NaN                   NaN
# 124  NaN  Atlético Madrid  ...                   NaN                   NaN
# 150  NaN    Qaırat Almaty  ...                   NaN                   NaN
# 180  NaN       Villarreal  ...            219.000000             38.000000
# 233  NaN           Getafe  ...                   NaN                   NaN
# 260  NaN         Juventus  ...            212.333333             37.333333
# 294  NaN        Barcelona  ...            249.333333             38.333333
# 349  NaN         Valencia  ...                   NaN                   NaN
# 355  NaN        Liverpool  ...            184.333333             28.333333
# 406  NaN   Rayo Vallecano  ...                   NaN                   NaN
# 440  NaN            Elche  ...                   NaN                   NaN
# 470  NaN       Olympiacos  ...            299.000000             51.000000
# 499  NaN           Girona  ...                   NaN                   NaN
# 557  NaN       Celta Vigo  ...                   NaN                   NaN
# 585  NaN  Manchester City  ...            175.000000             34.000000
# 607  NaN           Alavés  ...                   NaN                   NaN
# 648  NaN          Sevilla  ...                   NaN                   NaN
# 690  NaN            Betis  ...                   NaN                   NaN
# 714  NaN    Athletic Club  ...            119.000000             22.333333
# 743  NaN          Levante  ...                   NaN                   NaN
# 759  NaN           Monaco  ...            154.666667             17.333333
# 804  NaN       Villarreal  ...            219.000000             38.000000
# 844  NaN          Benfica  ...            196.000000             46.000000
# 882  NaN   Rayo Vallecano  ...                   NaN                   NaN
# 909  NaN         Valencia  ...                   NaN                   NaN
# 933  NaN    Real Sociedad  ...                   NaN                   NaN
# 965  NaN          Osasuna  ...                   NaN                   NaN
# 998  NaN           Getafe  ...                   NaN                   NaN
# 1042 NaN       Celta Vigo  ...                   NaN                   NaN
# 1060 NaN            Elche  ...                   NaN                   NaN
# 1099 NaN  Atlético Madrid  ...                   NaN                   NaN
# 1126 NaN         Mallorca  ...                   NaN                   NaN
# 1149 NaN           Girona  ...                   NaN                   NaN
# 1176 NaN            Betis  ...                   NaN                   NaN
# 1182 NaN           Alavés  ...                   NaN                   NaN
# 1225 NaN         Espanyol  ...                   NaN                   NaN
# 1249 NaN        Barcelona  ...            249.333333             38.333333
# 1263 NaN           Oviedo  ...                   NaN                   NaN
# 1277 NaN          Sevilla  ...                   NaN                   NaN
# 1298 NaN    Athletic Club  ...            119.000000             22.333333
#
#       opp_avg_Succ%_poss  opp_avg_PrgDist_poss  opp_avg_1/3_poss  \
# 14                   NaN                   NaN               NaN
# 42             37.300000           1101.000000         12.666667
# 76                   NaN                   NaN               NaN
# 105                  NaN                   NaN               NaN
# 124                  NaN                   NaN               NaN
# 150                  NaN                   NaN               NaN
# 180            46.300000           1303.333333         19.333333
# 233                  NaN                   NaN               NaN
# 260            39.766667           1145.666667         20.000000
# 294            49.433333           1410.333333         16.666667
# 349                  NaN                   NaN               NaN
# 355            41.866667           1032.000000         14.333333
# 406                  NaN                   NaN               NaN
# 440                  NaN                   NaN               NaN
# 470            40.900000            999.000000         17.000000
# 499                  NaN                   NaN               NaN
# 557                  NaN                   NaN               NaN
# 585            42.666667           1167.000000         16.333333
# 607                  NaN                   NaN               NaN
# 648                  NaN                   NaN               NaN
# 690                  NaN                   NaN               NaN
# 714            53.900000            724.666667          9.666667
# 743                  NaN                   NaN               NaN
# 759            49.600000           1011.666667         14.666667
# 804            46.300000           1303.333333         19.333333
# 844            76.000000           1372.000000         19.000000
# 882                  NaN                   NaN               NaN
# 909                  NaN                   NaN               NaN
# 933                  NaN                   NaN               NaN
# 965                  NaN                   NaN               NaN
# 998                  NaN                   NaN               NaN
# 1042                 NaN                   NaN               NaN
# 1060                 NaN                   NaN               NaN
# 1099                 NaN                   NaN               NaN
# 1126                 NaN                   NaN               NaN
# 1149                 NaN                   NaN               NaN
# 1176                 NaN                   NaN               NaN
# 1182                 NaN                   NaN               NaN
# 1225                 NaN                   NaN               NaN
# 1249           49.433333           1410.333333         16.666667
# 1263                 NaN                   NaN               NaN
# 1277                 NaN                   NaN               NaN
# 1298           53.900000            724.666667          9.666667
#
#       opp_avg_SCA_gsc  opp_avg_PassLive_gsc  opp_avg_Tkl+Int_def  \
# 14                NaN                   NaN                  NaN
# 42          31.666667             23.666667            21.000000
# 76                NaN                   NaN                  NaN
# 105               NaN                   NaN                  NaN
# 124               NaN                   NaN                  NaN
# 150               NaN                   NaN                  NaN
# 180         34.000000             26.666667            21.666667
# 233               NaN                   NaN                  NaN
# 260         40.333333             31.000000            27.666667
# 294         38.666667             29.666667            19.666667
# 349               NaN                   NaN                  NaN
# 355         23.333333             20.000000            22.000000
# 406               NaN                   NaN                  NaN
# 440               NaN                   NaN                  NaN
# 470         50.000000             34.000000             0.000000
# 499               NaN                   NaN                  NaN
# 557               NaN                   NaN                  NaN
# 585         26.000000             18.333333            26.000000
# 607               NaN                   NaN                  NaN
# 648               NaN                   NaN                  NaN
# 690               NaN                   NaN                  NaN
# 714         19.666667             15.333333            18.333333
# 743               NaN                   NaN                  NaN
# 759         13.000000             11.000000            22.666667
# 804         34.000000             26.666667            21.666667
# 844         41.000000             28.000000             8.000000
# 882               NaN                   NaN                  NaN
# 909               NaN                   NaN                  NaN
# 933               NaN                   NaN                  NaN
# 965               NaN                   NaN                  NaN
# 998               NaN                   NaN                  NaN
# 1042              NaN                   NaN                  NaN
# 1060              NaN                   NaN                  NaN
# 1099              NaN                   NaN                  NaN
# 1126              NaN                   NaN                  NaN
# 1149              NaN                   NaN                  NaN
# 1176              NaN                   NaN                  NaN
# 1182              NaN                   NaN                  NaN
# 1225              NaN                   NaN                  NaN
# 1249        38.666667             29.666667            19.666667
# 1263              NaN                   NaN                  NaN
# 1277              NaN                   NaN                  NaN
# 1298        19.666667             15.333333            18.333333
#
#      opp_avg_TklW_def  opp_avg_Tkl%_def
# 14                NaN               NaN
# 42          11.000000         58.333333
# 76                NaN               NaN
# 105               NaN               NaN
# 124               NaN               NaN
# 150               NaN               NaN
# 180          7.333333         48.733333
# 233               NaN               NaN
# 260         10.666667         53.066667
# 294          7.333333         52.733333
# 349               NaN               NaN
# 355         10.000000         54.566667
# 406               NaN               NaN
# 440               NaN               NaN
# 470         19.000000         73.900000
# 499               NaN               NaN
# 557               NaN               NaN
# 585         10.000000         50.433333
# 607               NaN               NaN
# 648               NaN               NaN
# 690               NaN               NaN
# 714          8.666667         46.933333
# 743               NaN               NaN
# 759          6.666667         38.900000
# 804          7.333333         48.733333
# 844          6.333333         50.000000
# 882               NaN               NaN
# 909               NaN               NaN
# 933               NaN               NaN
# 965               NaN               NaN
# 998               NaN               NaN
# 1042              NaN               NaN
# 1060              NaN               NaN
# 1099              NaN               NaN
# 1126              NaN               NaN
# 1149              NaN               NaN
# 1176              NaN               NaN
# 1182              NaN               NaN
# 1225              NaN               NaN
# 1249         7.333333         52.733333
# 1263              NaN               NaN
# 1277              NaN               NaN
# 1298         8.666667         46.933333
#
# [43 rows x 91 columns]

# %% [markdown]
# ### Writing the final dataset as a csv so it can be used to predict the model

# %%
matches_past.to_csv("matches_past_features.csv", index=False)
matches_future.to_csv("matches_future_features.csv", index=False)
